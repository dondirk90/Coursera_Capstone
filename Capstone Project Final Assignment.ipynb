# %% [markdown]
# ## Introduction
#
# In this project I will explore the culinaric possibilities in Cologne. It is a city which has a diverse offering of different Bars Restaurants and Cafes and it is nearly impossible to get to know all of them, not mentioning that there are closing and opening up new venues from time to time. As a person living in or visiting this city, there is so much to explore and a goal of this project is to help identifying those venues that are worth visiting.
# As a way of achieving this, I tried to model a basic scoring system, that takes into account the rating, the price and the distance of the venue depending on the current location. It then recommends you a list of venues with the best scoring, independent of the actual category of the venue. Therefore this method is not really suitable for all user, for instance those who look for a specific kind of venue or cuisine. However, for users that are new to the city it provides venues that are objectively worth visiting.
#
# ## Data
# The available FourSquare location Data via the Foursquare API provide us with the necessary information to visualize the restaurants that are spread throughout the city. On a more detailed point of view, we can dive into specific neigbourhood or streets and find the best rated venues, the distance to the venue and the respective price category.
# All postal codes from the city of Cologne are available on "https://www.koeln.de/postleitzahlen" and the necessary location from the respective Cologne postal codes can be found on "http://www.fa-technik.adfc.de/code/opengeodb/PLZ.tab", which is a csv-file, similar to the Toronto example we had troughout the course.
#
# ## Methodology
# Postal code data will be collected from https://www.koeln.de/postleitzahlen, cleaned and processed into a dataframe.
# The respective location data is read into a dataframe from the mentioned csv-file and merged with the postal code data including the neigbourhood names.
# With the available location data we will use our Foursquare Developer account to fetch the detailed venue information such as category, price, rating etc.
# Then we create a score with the available venue information to output those venues that are ranked highest with our applied scoring system. These are the venues that are reccommended to visit.
#
# ## Problem Statement
# What are the objectively best venues to visit in the current area?

# %% [markdown]
# To see that, let's start bei installing and importing all necessary libraries

# %%
pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.11.0-py2.py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 4.5 MB/s  eta 0:00:01
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.24.0)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (1.18.5)
# Collecting branca>=0.3.0
#   Downloading branca-0.4.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.11.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.1 folium-0.11.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis
import requests # library to handle requests

from bs4 import BeautifulSoup
import os

import folium # map rendering library

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

# Matplotlib and associated plotting modules
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
# %matplotlib inline

import seaborn as sns

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# Now define the necessary functions

# %%
def geo_location(address):
    # get geo location of address
    geolocator = Nominatim(user_agent="foursquare_agent")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    return latitude,longitude

# %%
location = geo_location("Cologne")
latitude, longitude = location

# %%
url = requests.get('https://www.koeln.de/postleitzahlen')
url.content
soup = BeautifulSoup(url.content, "lxml")
list_plz = []
for plz_html in soup.find_all("ul", attrs={"class":"plz"}):
    for plz in plz_html.find_all('li'):
        list_plz.append(plz.text)

df = pd.DataFrame(list_plz, columns=["plz"])
df.dtypes
# Out:
# plz    object
# dtype: object

# %%
try:
    from urllib.request import Request, urlopen  # Python 3
except ImportError:
    from urllib2 import Request, urlopen  # Python 2

df_geo = pd.read_csv("http://www.fa-technik.adfc.de/code/opengeodb/PLZ.tab", sep='\t',  dtype=str)
df_geo

df = df.merge(df_geo, on ='plz', how='left')
df
# Out:
#       plz #loc_id               lon               lat   Ort
# 0   50667    8321  6.95768491832349  50.9400886235176  Köln
# 1   50668    8322  6.96545005139455   50.950695435874  Köln
# 2   50670    8323  6.95095743959049  50.9511722093173  Köln
# 3   50672    8309   6.9384761893034  50.9434409895397  Köln
# 4   50674    8324  6.93704081933882   50.933583841904  Köln
# 5   50676    8325  6.95555962327279  50.9329782103951  Köln
# 6   50677    8326  6.95323649210595  50.9225551674677  Köln
# 7   50678    8327  6.96648245395115  50.9240361563136  Köln
# 8   50679    8328  6.98103226157441  50.9374228290525  Köln
# 9   50733    8329  6.95639738632809  50.9651646910743  Köln
# 10  50735    8330  6.96489890149431  50.9913171833546  Köln
# 11  50737    8331  6.93498331604672   50.993196838708  Köln
# 12  50739    8332   6.9240225670199  50.9812320143603  Köln
# 13  50765    8333  6.86968716985314   51.019589224513  Köln
# 14  50767    8334  6.88760346946062  51.0037346396584  Köln
# 15  50769    8335  6.87761169901364  51.0469489567741  Köln
# 16  50823    8336  6.92862745338528  50.9519924217254  Köln
# 17  50825    8337  6.91253656178859  50.9553179681971  Köln
# 18  50827    8338  6.89885561277817  50.9698326231472  Köln
# 19  50829    8339  6.87241948299702  50.9749044984683  Köln
# 20  50858    8340   6.8584682665981  50.9252511758982  Köln
# 21  50859    8341  6.83462461784078  50.9549261078613  Köln
# 22  50931    8342  6.92098837394734  50.9328776482785  Köln
# 23  50933    8343   6.8783124941137  50.9437445440682  Köln
# 24  50935    8344  6.89676568824227  50.9237126215185  Köln
# 25  50937    8345  6.91282587936387  50.9123294308452  Köln
# 26  50939    8346  6.92844621579179  50.9102884578719  Köln
# 27  50968    8349  6.96844353110743     50.9037842288  Köln
# 28  50969    8350  6.94193781111677  50.9069124451012  Köln
# 29  50996    8351   6.9908172640553  50.8841098990908  Köln
# 30  50997    8352  6.95308266153851  50.8663790428213  Köln
# 31  50999    8347   7.0222387516286  50.8770568945016  Köln
# 32  51061    8348  7.00609153670045  50.9971300696136  Köln
# 33  51063    8353  7.00793340462762  50.9699227357995  Köln
# 34  51065    8354  7.01388384647454  50.9560547323864  Köln
# 35  51067    8355  7.04469416608063  50.9667022577576  Köln
# 36  51069    8356  7.06176762760747  50.9904944081114  Köln
# 37  51103    8357  7.01889275778818  50.9426828988977  Köln
# 38  51105    8358  6.99861786584936  50.9187952163133  Köln
# 39  51107    8359  7.08609986062232  50.9238058360714  Köln
# 40  51109    8360  7.08523919170645  50.9430823925346  Köln
# 41  51143    8361  7.03911986011605  50.8611091527063  Köln
# 42  51145    8362  7.08329954642419  50.8835904430413  Köln
# 43  51147    8363  7.10995826326036  50.8700551931042  Köln
# 44  51149    8364  7.04890860805438  50.9063673004448  Köln

# %%
# create map of Cologne using latitude and longitude values
map_cologne = folium.Map(location=location, zoom_start=12)

# add markers to map
for lat, lng, Ort, plz in zip(df['lat'], df['lon'], df['Ort'], df['plz']):
    label = '{}, {}'.format(Ort, plz)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_cologne)  
    
map_cologne
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now we sign into our FourSquare Developer account

# %%
CLIENT_ID = 'OSEO0CTWLPBA5D4C3SUQ55EE1JLPPPAIYN3RYAECQUI10L3U' # your Foursquare ID
CLIENT_SECRET = 'ENUQSRXBH00V30AEHILA3QP5HLCXHRDH2HNVQFMG5HIAGHGX' # your Foursquare Secret
ACCESS_TOKEN = 'UNOFVKGGOI1JNSOCH43MV2LQHGFGUG4CBTED51J53A4M0UEA' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 200
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: OSEO0CTWLPBA5D4C3SUQ55EE1JLPPPAIYN3RYAECQUI10L3U
# CLIENT_SECRET:ENUQSRXBH00V30AEHILA3QP5HLCXHRDH2HNVQFMG5HIAGHGX

# %% [markdown]
# Filter those results on category ID "4d4b7105d754a06374d81259", which is Food Places, and set the limit to 750 meters.

# %%
category = '4d4b7105d754a06374d81259'
radius = 750

# %% [markdown]
# Define a function that return the location data of a specific area code.

# %%
#create function to get location of plz
def get_location(area_code):
    # get geo location of area code
    s= df[df['plz'] == area_code]
    latitude_plz = s['lat'].values[0]
    longitude_plz = s['lon'].values[0]
    return latitude_plz, longitude_plz

# %% [markdown]
# For my example we seek for the longitude and latitude of the postal code "50674", which is the area I am living in.

# %%
latitude, longitude = get_location('50674')

# %% [markdown]
# Then create the url to request the venue information

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&categoryId={}&radius={}&limit{}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, category, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=OSEO0CTWLPBA5D4C3SUQ55EE1JLPPPAIYN3RYAECQUI10L3U&client_secret=ENUQSRXBH00V30AEHILA3QP5HLCXHRDH2HNVQFMG5HIAGHGX&ll=50.933583841904,6.93704081933882&oauth_token=UNOFVKGGOI1JNSOCH43MV2LQHGFGUG4CBTED51J53A4M0UEA&v=20180604&categoryId=4d4b7105d754a06374d81259&radius=750&limit200'

# %% [markdown]
# Define some functions to 1) get a list a venue depending on the location point and 2) get the detailed information of the venueID.

# %%
def get_venues(latitude,longitude):
    #set variables
    radius=750
    LIMIT=100
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&categoryId={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            latitude, 
            longitude, 
            radius, 
            LIMIT,
            category)
    # get all the data
    results = requests.get(url).json()
    venue_data=results['response']['groups'][0]['items']
    venue_details=[]
    for row in venue_data:
        try:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_distance=row['venue']['location']['distance']
            venue_plz=row['venue']['location']['postalCode']
            venue_address=row['venue']['location']['address']
            venue_details.append([venue_id,venue_name,venue_category, venue_distance, venue_plz, venue_address])
        except KeyError:
            pass
    column_names=['ID','Name','Category', 'Distance', 'PostalCode', 'Address']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df


def get_venue_details(venue_id):
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    #get all the data
    results = requests.get(url).json()
    #print(results)
    venue_data=results['response']['venue']
    print(venue_data)
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_price=venue_data['price']['tier']
        #venue_price=venue_data['listed']['groups']['attributes']['groups']['items']['priceTier']
        venue_rating=venue_data['rating']
        print(venue_price)
        venue_details.append([venue_id,venue_name,venue_price,venue_rating])
        print(venue_details)
    except KeyError:
        pass
    column_names=['ID','Name','Price','Rating']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %%
get_venue_details('4b27e448f964a520cc8b24e3')
# Out:
# {'id': '4b27e448f964a520cc8b24e3', 'name': 'Brauhaus A. Pütz', 'contact': {'phone': '+49221211166', 'formattedPhone': '+49 221 211166'}, 'location': {'address': 'Engelbertstr. 67', 'lat': 50.93512, 'lng': 6.9377885, 'labeledLatLngs': [{'label': 'display', 'lat': 50.93512, 'lng': 6.9377885}], 'postalCode': '50674', 'cc': 'DE', 'city': 'Köln', 'state': 'Nordrhein-Westfalen', 'country': 'Deutschland', 'formattedAddress': ['Engelbertstr. 67', '50674 Köln', 'Deutschland']}, 'canonicalUrl': 'https://foursquare.com/v/brauhaus-a-p%C3%BCtz/4b27e448f964a520cc8b24e3', 'categories': [{'id': '50327c8591d4c4b30a586d5d', 'name': 'Brewery', 'pluralName': 'Breweries', 'shortName': 'Brewery', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 21}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '€'}, 'likes': {'count': 102, 'groups': [{'type': 'others', 'count': 102, 'items': []}], 'summary': '102 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.3, 'ratingColor': '73CF42', 'ratingSignals': 130, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 50, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 50, 'items': [{'id': '4fca010ce4b0c8f85c05e4b2', 'createdAt': 1338638604, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/gnlBtAHTAJVX0PiNZg0AuCK-3qFo-plfUqq2GtP0WQU.jpg', 'width': 720, 'height': 537, 'user': {'isSanctioned': False, 'firstName': 'Jeroen', 'lastName': 'v', 'countryCode': 'NL'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1260905544, 'tips': {'count': 21, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 21, 'items': [{'id': '52d2858c498e76e9bce0967d', 'createdAt': 1389528460, 'text': 'Frisch Gezapftes von der Mühle. Dazu Brauhauskost Deluxe. Sehr gut!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/52d2858c498e76e9bce0967d', 'lang': 'de', 'likes': {'count': 2, 'groups': [{'type': 'others', 'count': 2, 'items': [{'isSanctioned': False, 'firstName': 'Harry', 'lastName': 'M', 'countryCode': 'GB'}, {'isSanctioned': False, 'firstName': 'Franz', 'lastName': 'G', 'countryCode': 'DE'}]}], 'summary': '2 likes'}, 'logView': True, 'agreeCount': 2, 'disagreeCount': 0, 'todo': {'count': 1}, 'user': {'isSanctioned': False, 'firstName': 'Holger', 'lastName': 'B', 'countryCode': 'DE'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/beXVDm', 'timeZone': 'Europe/Berlin', 'listed': {'count': 90, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 90, 'items': [{'id': '509fb872e4b0d459dcdad7ab', 'name': 'NEIGHBORHOOD', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Marcus', 'lastName': 'S', 'countryCode': 'DE'}, 'editable': False, 'public': True, 'collaborative': True, 'url': '/user/40984359/list/neighborhood', 'canonicalUrl': 'https://foursquare.com/user/40984359/list/neighborhood', 'createdAt': 1352644722, 'updatedAt': 1399296402, 'followers': {'count': 4}, 'listItems': {'count': 50, 'items': [{'id': 'v4b27e448f964a520cc8b24e3', 'createdAt': 1352646766}]}}, {'id': '50afd8dfe4b0062753accd1f', 'name': 'Bars', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Marcus', 'lastName': 'C', 'countryCode': 'DE'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/381584/list/bars', 'canonicalUrl': 'https://foursquare.com/user/381584/list/bars', 'createdAt': 1353701599, 'updatedAt': 1428093785, 'photo': {'id': '5084f2c5e4b07ddb62c8bf4c', 'createdAt': 1350890181, ' ...
# 2
# [['4b27e448f964a520cc8b24e3', 'Brauhaus A. Pütz', 2, 8.3]]
#                          ID              Name  Price  Rating
# 0  4b27e448f964a520cc8b24e3  Brauhaus A. Pütz      2     8.3

# %%
plz_venues = get_venues(latitude,longitude).sort_values(by=['Distance'])
plz_venues
# Out:
#                           ID         Name             Category  Distance  \
# 5   5c084427061b51002c127368  Tapeo & Co.     Tapas Restaurant        81
# 3   57645427498e7a5746a35766       Tanica   Italian Restaurant       142
# 80  5a3a15691f8ed64718884d30   Tigermilch  Peruvian Restaurant       176
# 0   583ec82c19b1ad33a488ae04       mikoto     Sushi Restaurant       196
# 2   4b05886bf964a52082c422e3  Café Wahlen                 Café       206
# ..                       ...          ...                  ...       ...
# 82  4ee268668231cd14a32afac3   Shaka Zulu   African Restaurant       716
# 85  5159889ee4b0655021dd3bd5    Hot Point   Chinese Restaurant       719
# 83  4fb50c37e4b0186ba39cc480     Caveedel                 Café       724
# 94  4d91eae49acaa143a55af2f0      Lakshmi    Indian Restaurant       738
# 75  541c3701498ed1e0072d104f     Häppchen                 Café       750
#
#    PostalCode                 Address
# 5       50674           Lindenstr. 38
# 3       50674      Engelbertstraße 31
# 80      50674       Brüsseler Str. 12
# 0       59674     Hohenstaufenring 55
# 2       50674     Hohenstaufenring 64
# ..        ...                     ...
# 82      50672       Limburger Str. 29
# 85      50667           Salierring 44
# 83      50672       Brüsseler Str. 69
# 94      50676  Thieboldsgasse 101-103
# 75      50674     Otto-Fischer-Str. 9
#
# [95 rows x 6 columns]

# %%
dfObj = pd.DataFrame(columns=['ID' 'Price', 'Rating'])
for column in plz_venues['ID']:
        try:
            detail=get_venue_details(column)
            dfObj = pd.concat([dfObj, detail])
        except KeyError:
            pass
# Out:
# {'id': '5c084427061b51002c127368', 'name': 'Tapeo & Co.', 'contact': {'phone': '+4922182082000', 'formattedPhone': '+49 221 82082000'}, 'location': {'address': 'Lindenstr. 38', 'crossStreet': 'Jean-Claude-Letist-Platz', 'lat': 50.93382, 'lng': 6.935945, 'labeledLatLngs': [{'label': 'display', 'lat': 50.93382, 'lng': 6.935945}], 'postalCode': '50674', 'cc': 'DE', 'city': 'Köln', 'state': 'Nordrhein-Westfalen', 'country': 'Deutschland', 'formattedAddress': ['Lindenstr. 38 (Jean-Claude-Letist-Platz)', '50674 Köln', 'Deutschland']}, 'canonicalUrl': 'https://foursquare.com/v/tapeo--co/5c084427061b51002c127368', 'categories': [{'id': '4bf58dd8d48988d1db931735', 'name': 'Tapas Restaurant', 'pluralName': 'Tapas Restaurants', 'shortName': 'Tapas', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d11e941735', 'name': 'Cocktail Bar', 'pluralName': 'Cocktail Bars', 'shortName': 'Cocktail', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 1}, 'price': {'tier': 1, 'message': 'Cheap', 'currency': '€'}, 'likes': {'count': 8, 'groups': [{'type': 'others', 'count': 8, 'items': [{'isSanctioned': False, 'firstName': 'Zizi', 'countryCode': 'DE'}, {'isSanctioned': False, 'firstName': 'Gianna', 'lastName': 'B', 'countryCode': 'DE'}, {'isSanctioned': False, 'firstName': 'Oliver', 'lastName': 'D', 'countryCode': 'DE'}, {'isSanctioned': False, 'firstName': 'Marius', 'lastName': 'P', 'countryCode': 'DE'}]}], 'summary': '8 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.0, 'ratingColor': '73CF42', 'ratingSignals': 9, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 8, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 8, 'items': [{'id': '5f443b93ff0a772a3b4fc473', 'createdAt': 1598307219, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/40009139_VfdurD9bBNeQ9UOagg4gY5zuc1QjXe9BapyjxeRwlzo.jpg', 'width': 1920, 'height': 1440, 'user': {'isSanctioned': False, 'firstName': '@Monsieur.Clement', 'countryCode': 'DE'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1544045607, 'tips': {'count': 1, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 1, 'items': [{'id': '5c65fe8016fa04002c30aff2', 'createdAt': 1550188160, 'text': 'Die Tapas und die vielen Sangria Kreationen 😍', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5c65fe8016fa04002c30aff2', 'photo': {'id': '5c65fe815a2c91002cb8185c', 'createdAt': 1550188161, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/40009139_fRPUHK2saoAOX7jofVoQgzA-1oMuqY1NZwaj5rEXh1U.jpg', 'width': 1920, 'height': 1438, 'visibility': 'public'}, 'photourl': 'https://fastly.4sqi.net/img/general/original/40009139_fRPUHK2saoAOX7jofVoQgzA-1oMuqY1NZwaj5rEXh1U.jpg', 'lang': 'de', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': '@Monsieur.Clement', 'countryCode': 'DE'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'https://4sq.com/2EeSm1j', 'timeZone': 'Europe/Berlin', 'listed': {'count': 4, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 4, 'items': [{'id': '5835e519d60c8b043286c9ba', 'name': 'Tapas', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Marcel', 'lastName': 'R', 'countryCode': 'DE'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/32917459/list/tapas', 'canonicalUrl': 'https://foursqua ...
# 1
# [['5c084427061b51002c127368', 'Tapeo & Co.', 1, 8.0]]
# {'id': '57645427498e7a5746a35766', 'name': 'Tanica', 'contact': {'phone': '+492212405271', 'formattedPhone': '+49 221 2405271'}, 'location': {'address': 'Engelbertstraße 31', 'lat': 50.93293187973706, 'lng': 6.938787886173503, 'labeledLatLngs': [{'label': 'display', 'lat': 50.93293187973706, 'lng': 6.938787886173503}], 'postalCode': '50674', 'cc': 'DE', 'city': 'Köln', 'state': 'Nordrhein-Westfalen', 'country': 'Deutschland', 'formattedAddress': ['Engelbertstraße 31', '50674 Köln', 'Deutschland']}, 'canonicalUrl': 'https://foursquare.com/v/tanica/57645427498e7a5746a35766', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 17}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '€'}, 'likes': {'count': 45, 'groups': [{'type': 'others', 'count': 45, 'items': []}], 'summary': '45 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.1, 'ratingColor': '73CF42', 'ratingSignals': 65, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 11, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 11, 'items': [{'id': '5ee8dd3d300a950008cd0330', 'createdAt': 1592319293, 'source': {'name': 'Foursquare for Android', 'url': 'https://foursquare.com/download/#/android'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/462698923_LVKHn0ZodMqk_-VkwZZEtEvqRmFCDsrgYxnxYjebV9Q.jpg', 'width': 720, 'height': 960, 'user': {'isSanctioned': False, 'firstName': 'Kat', 'countryCode': 'DE'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1466192935, 'tips': {'count': 17, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 17, 'items': [{'id': '5d89bfb4bff45e00078306f8', 'createdAt': 1569308596, 'text': 'We experienced a friendly and sympathetic welcome, an excellent service and had good food and drink - very nice wine list! I liked the atmosphere!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5d89bfb4bff45e00078306f8', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Tino', 'lastName': 'U', 'countryCode': 'FR'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/1tAMxlC', 'timeZone': 'Europe/Berlin', 'listed': {'count': 42, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 42, 'items': [{'id': '57a5d0e3498ec6567cf28000', 'name': 'Köln', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Christopher', 'lastName': 'R', 'countryCode': 'GB'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/158135972/list/k%C3%B6ln', 'canonicalUrl': 'https://foursquare.com/user/158135972/list/k%C3%B6ln', 'createdAt': 1470484707, 'updatedAt': 1554692103, 'photo': {'id': '52744e7211d2b8a3b6d694c5', 'createdAt': 1383353970, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/3481753_aCORqzdjhuMw5yCu3skjeT1H-L7Jijp2P-CP-CjFXgE.jpg', 'width': 817, 'height': 720, 'user': {'isSanctioned': False, 'firstName': 'alxxrt', 'countryCode': 'DE'}, 'visibility': 'public'}, 'followers': {'count': 0}, 'listItems': {'count': 16, 'items': [{'id': 'v57645427498e7a5746a35766', 'createdAt': 1495469145}]}}, {'id': '5ee8de815b3c66146a2e18c4', 'name': 'Köln', 'description': 'Abendessen', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Kat', 'countryCode': 'DE'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/462698923/list/k%C3%B6ln', ...
# 2
# [['57645427498e7a5746a35766', 'Tanica', 2, 8.1]]
# {'id': '5a3a15691f8ed64718884d30', 'name': 'Tigermilch', 'contact': {'phone': '+4922175985821', 'formattedPhone': '+49 221 75985821', 'facebook': '937229539654371', 'facebookUsername': 'tigermilch.kitchen', 'facebookName': 'Tigermilch'}, 'location': {'address': 'Brüsseler Str. 12', 'crossStreet': 'Jülicher Straße', 'lat': 50.934082, 'lng': 6.934651, 'labeledLatLngs': [{'label': 'display', 'lat': 50.934082, 'lng': 6.934651}], 'postalCode': '50674', 'cc': 'DE', 'city': 'Köln', 'state': 'Nordrhein-Westfalen', 'country': 'Deutschland', 'formattedAddress': ['Brüsseler Str. 12 (Jülicher Straße)', '50674 Köln', 'Deutschland']}, 'canonicalUrl': 'https://foursquare.com/v/tigermilch/5a3a15691f8ed64718884d30', 'categories': [{'id': '4eb1bfa43b7b52c0e1adc2e8', 'name': 'Peruvian Restaurant', 'pluralName': 'Peruvian Restaurants', 'shortName': 'Peruvian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/peruvian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 8}, 'url': 'http://tigermilch.kitchen', 'price': {'tier': 1, 'message': 'Cheap', 'currency': '€'}, 'likes': {'count': 18, 'groups': [{'type': 'others', 'count': 18, 'items': []}], 'summary': '18 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.0, 'ratingColor': 'C5DE35', 'ratingSignals': 29, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 12, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 12, 'items': [{'id': '5f02ce424554f15f398e2a17', 'createdAt': 1594019394, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/513320344_CXceB7hiwbzc5YV4HHOQ_bNhTSu2kecuxwmRI9a_sgY.jpg', 'width': 1440, 'height': 1920, 'user': {'isSanctioned': False, 'firstName': 'Gelatano', 'countryCode': 'DE'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1513756009, 'tips': {'count': 8, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 8, 'items': [{'id': '5d3c4be77ca2450008018864', 'createdAt': 1564232679, 'text': 'Zwar ist es etwas laut, aber das machen der super Service und das unfassbar köstliche essen wett. Sehr zu empfehlen', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5d3c4be77ca2450008018864', 'photo': {'id': '5d3c4be8702b37000816c9d7', 'createdAt': 1564232680, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/93709450_pPCgYuFsTcc2Ig2dzL0Ebd0EXEun3FUhA-xwO22VGSU.jpg', 'width': 1440, 'height': 1488, 'visibility': 'public'}, 'photourl': 'https://fastly.4sqi.net/img/general/original/93709450_pPCgYuFsTcc2Ig2dzL0Ebd0EXEun3FUhA-xwO22VGSU.jpg', 'lang': 'de', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 1, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Vanessa', 'lastName': 'F', 'countryCode': 'GR'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/2kOfzLK', 'timeZone': 'Europe/Berlin', 'listed': {'count': 26, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 26, 'items': [{'id': '57096c6a498e28e0649c165c', 'name': "To Do's @ KÖLN", 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Sarah', 'lastName': 'T', 'countryCode': 'DE'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/153440566/list/to-dos--k%C3%B6ln', 'canonicalUrl': 'https://foursquare.com/user/153440566/list/to-dos--k%C3%B6ln', 'createdAt': 1460235370, 'updatedAt': 1602884589, 'photo': {'id': '521d90e511d23ecb2aa6152d', 'createdAt': 1377669349, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/57206080_W_E8gmj9mi5vZbmpfGkWYnGkjTJNbkwkKWTCfsRO8fE.jpg', 'width': 717, ...
# 1
# [['5a3a15691f8ed64718884d30', 'Tigermilch', 1, 7.0]]
# {'id': '583ec82c19b1ad33a488ae04', 'name': 'mikoto', 'contact': {'phone': '+4922129832294', 'formattedPhone': '+49 221 29832294'}, 'location': {'address': 'Hohenstaufenring 55', 'lat': 50.93320395767124, 'lng': 6.939779064336179, 'labeledLatLngs': [{'label': 'display', 'lat': 50.93320395767124, 'lng': 6.939779064336179}], 'postalCode': '59674', 'cc': 'DE', 'city': 'Köln', 'state': 'Nordrhein-Westfalen', 'country': 'Deutschland', 'formattedAddress': ['Hohenstaufenring 55', '59674 Köln', 'Deutschland']}, 'canonicalUrl': 'https://foursquare.com/v/mikoto/583ec82c19b1ad33a488ae04', 'categories': [{'id': '4bf58dd8d48988d1d2941735', 'name': 'Sushi Restaurant', 'pluralName': 'Sushi Restaurants', 'shortName': 'Sushi', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 8}, 'url': 'http://www.mikotosushi.de', 'price': {'tier': 1, 'message': 'Cheap', 'currency': '€'}, 'likes': {'count': 22, 'groups': [{'type': 'others', 'count': 22, 'items': []}], 'summary': '22 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.6, 'ratingColor': '73CF42', 'ratingSignals': 28, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 23, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 23, 'items': [{'id': '58a209e8fb9d8959233499d7', 'createdAt': 1487014376, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/337666316_4HIf1dc_ABYLxgG91L--f3QoQzqaLIHeMABwMG3DIxw.jpg', 'width': 1440, 'height': 1440, 'user': {'isSanctioned': False, 'firstName': 'merrykay_cgn', 'countryCode': 'DE'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1480509484, 'tips': {'count': 8, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 8, 'items': [{'id': '5d62f9cca8b108000673edc9', 'createdAt': 1566767564, 'text': 'Below average', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5d62f9cca8b108000673edc9', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Al', 'lastName': 'M', 'countryCode': 'DE'}, 'authorInteractionType': 'meh'}]}]}, 'shortUrl': 'http://4sq.com/2g6bhLU', 'timeZone': 'Europe/Berlin', 'listed': {'count': 62, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 62, 'items': [{'id': '59b6d35bccad6b02f62555ba', 'name': 'Dinner', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Hannah', 'lastName': 'K', 'countryCode': 'DE'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/446901019/list/dinner', 'canonicalUrl': 'https://foursquare.com/user/446901019/list/dinner', 'createdAt': 1505153883, 'updatedAt': 1506683652, 'followers': {'count': 1}, 'listItems': {'count': 46, 'items': [{'id': 'v583ec82c19b1ad33a488ae04', 'createdAt': 1506683652}]}}, {'id': '54ce2850498e05c4ba407c6d', 'name': 'Köln', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'JPT', 'countryCode': 'DE'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/missjennigirl/list/k%C3%B6ln', 'canonicalUrl': 'https://foursquare.com/missjennigirl/list/k%C3%B6ln', 'createdAt': 1422796880, 'updatedAt': 1516895134, 'followers': {'count': 0}, 'listItems': {'count': 36, 'items': [{'id': 'v583ec82c19b1ad33a488ae04', 'createdAt': 1507832492}]}}, {'id': '50e20884e4b0e03a3b8c2151', 'name': 'Eat in Cologne', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Agustina', 'lastName': 'A', 'countryCode': 'DE'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/44798803/list/eat-in-co ...
# 1
# [['583ec82c19b1ad33a488ae04', 'mikoto', 1, 8.6]]
# {'id': '4b05886bf964a52082c422e3', 'name': 'Café Wahlen', 'contact': {'phone': '+49221231625', 'formattedPhone': '+49 221 231625', 'facebook': '122960714425785', 'facebookName': 'Café Wahlen'}, 'location': {'address': 'Hohenstaufenring 64', 'lat': 50.9338196801551, 'lng': 6.939958333969116, 'labeledLatLngs': [{'label': 'display', 'lat': 50.9338196801551, 'lng': 6.939958333969116}], 'postalCode': '50674', 'cc': 'DE', 'city': 'Köln', 'state': 'Nordrhein-Westfalen', 'country': 'Deutschland', 'formattedAddress': ['Hohenstaufenring 64', '50674 Köln', 'Deutschland']}, 'canonicalUrl': 'https://foursquare.com/v/caf%C3%A9-wahlen/4b05886bf964a52082c422e3', 'categories': [{'id': '4bf58dd8d48988d16d941735', 'name': 'Café', 'pluralName': 'Cafés', 'shortName': 'Café', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 17}, 'url': 'http://www.cafe-wahlen.de', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '€'}, 'likes': {'count': 62, 'groups': [{'type': 'others', 'count': 62, 'items': []}], 'summary': '62 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.2, 'ratingColor': '73CF42', 'ratingSignals': 83, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 51, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 51, 'items': [{'id': '4ff7055fe4b021ccc788b050', 'createdAt': 1341588831, 'source': {'name': 'Foursquare for Android', 'url': 'https://foursquare.com/download/#/android'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/9tJKPgjv32oHG-E3GFkJv4f_kIVnUHj5W0bFKUKnBkI.jpg', 'width': 720, 'height': 540, 'user': {'isSanctioned': False, 'firstName': 'Guenter', 'lastName': 'D', 'countryCode': 'DE'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1258653803, 'tips': {'count': 17, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 17, 'items': [{'id': '546a53d7498e8ba234b983a1', 'createdAt': 1416254423, 'text': 'Hier gibt es die besten Torten und Gebäckstücke aus ganz Köln. Die Einrichtung erinnert an Omas Zeiten. Die netten Servicedamen sind um keinen flotten Spruch verlegen.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/546a53d7498e8ba234b983a1', 'lang': 'de', 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'isSanctioned': False, 'firstName': 'Harry', 'lastName': 'M', 'countryCode': 'GB'}, {'isSanctioned': False, 'firstName': 'Thorsten', 'lastName': 'S', 'countryCode': 'DE'}, {'isSanctioned': False, 'firstName': 'Thorsten', 'lastName': 'S', 'countryCode': 'DE'}]}], 'summary': '3 likes'}, 'logView': True, 'agreeCount': 2, 'disagreeCount': 0, 'todo': {'count': 1}, 'user': {'isSanctioned': False, 'firstName': 'Patrick', 'lastName': 'W', 'countryCode': 'DE'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/cKLHU0', 'timeZone': 'Europe/Berlin', 'listed': {'count': 73, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 73, 'items': [{'id': '4ea2edb7e5e8ca72b7742d75', 'name': 'Best places in Köln, Bundesrepublik Deutschland', 'description': 'my very own list....', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Stefan', 'lastName': 'S', 'countryCode': 'DE'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/stevecgn/list/best-places-in-k%C3%B6ln-bundesrepublik-deutschland', 'canonicalUrl': 'https://foursquare.com/stevecgn/list/best-places-in-k%C3%B6ln-bundesrepublik-deutschland', 'createdAt': 1319300535, 'updatedAt': 1384043489, 'followers': {'count': 5}, 'listItems': {'count': 13, 'items': [{'id': 'v4b05886bf964a52082c422e3', 'createdAt': 1370787146}]}}, {'id': '566c311d498e06920a ...
# 2
# [['4b05886bf964a52082c422e3', 'Café Wahlen', 2, 8.2]]
# {'id': '5bd9ac2dcbcdee002c503fbd', 'name': 'Takumi', 'contact': {'phone': '+4922195628704', 'formattedPhone': '+49 221 95628704', 'instagram': 'takumikoeln', 'facebook': '263147114256688', 'facebookUsername': 'takumikoeln', 'facebookName': 'Takumi Köln'}, 'location': {'address': 'Hohenstaufenring 58', 'lat': 50.932925, 'lng': 6.940343, 'labeledLatLngs': [{'label': 'display', 'lat': 50.932925, 'lng': 6.940343}], 'postalCode': '50674', 'cc': 'DE', 'city': 'Köln', 'state': 'Nordrhein-Westfalen', 'country': 'Deutschland', 'formattedAddress': ['Hohenstaufenring 58', '50674 Köln', 'Deutschland']}, 'canonicalUrl': 'https://foursquare.com/v/takumi/5bd9ac2dcbcdee002c503fbd', 'categories': [{'id': '55a59bace4b013909087cb24', 'name': 'Ramen Restaurant', 'pluralName': 'Ramen Restaurants', 'shortName': 'Ramen', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 2}, 'url': 'http://takumi.koeln', 'likes': {'count': 7, 'groups': [{'type': 'others', 'count': 7, 'items': [{'isSanctioned': False, 'firstName': 'Praveen', 'lastName': 'C', 'countryCode': 'DE'}, {'isSanctioned': False, 'firstName': 'Vanessa', 'lastName': 'B', 'countryCode': 'DE'}, {'isSanctioned': False, 'firstName': 'Sarah', 'lastName': 'T', 'countryCode': 'DE'}, {'isSanctioned': False, 'firstName': 'Philipp', 'lastName': 'K', 'countryCode': 'DE'}]}], 'summary': '7 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.2, 'ratingColor': 'C5DE35', 'ratingSignals': 10, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 8, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 8, 'items': [{'id': '5eb2961b61cb2d00070a5dbe', 'createdAt': 1588762139, 'source': {'name': 'Yext Yext', 'url': 'http://yext.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/87388367_3DqmxLxcaqxU9TvlDxYJ5CXOiwlUsys6B_r43-QO_Ww.png', 'width': 521, 'height': 521, 'user': {'isSanctioned': False, 'firstName': 'Yext', 'lastName': 'Y', 'countryCode': 'US'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'description': '"Ramen ist unsere Passion und Leidenschaft! Das Highlight unserer Takumi Ramen sind die Ramen selbst, welche wir in drei verschiedenen Geschmacksrichtungen aus Hokkaido südlich Japans importieren, um Ihnen ein 100% originaltreues Geschmackserlebnis zu bieten...', 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1540992045, 'tips': {'count': 2, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 2, 'items': [{'id': '5f9de3533f5cb1168ab32d7d', 'createdAt': 1604182867, 'text': 'Teriyaki ramen', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5f9de3533f5cb1168ab32d7d', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Praveen', 'lastName': 'C', 'countryCode': 'DE'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'https://4sq.com/2P1lNda', 'timeZone': 'Europe/Berlin', 'listed': {'count': 9, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 9, 'items': [{'id': '578277bf498eb34b27dd8ef9', 'name': 'Köln', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Jan', 'lastName': 'L', 'countryCode': 'FI'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/214512946/list/k%C3%B6ln', 'canonicalUrl': 'https://foursquare.com/user/214512946/list/k%C3%B6ln', 'createdAt': 1468168127, 'updatedAt': 1603923744, 'followers': {'count': 0}, 'listItems': {'count': 120, 'items': [{'id': 'v5bd9ac2dcbcdee002c503fbd', 'createdAt': 1574591166}]}}, {'id': '5a49223a81635b5dca37077f', 'name': 'Köln', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'R.', 'lastName': 'L', 'countryCode': 'CA' ...
# {'id': '557ca611498ea86c7f1e1893', 'name': 'Kunstbruder', 'contact': {'phone': '+4922122200146', 'formattedPhone': '+49 221 22200146', 'twitter': 'kunstbruder', 'instagram': 'kunstbruder', 'facebook': '465462326798368', 'facebookUsername': 'Kunstbruder', 'facebookName': 'Kunstbruder'}, 'location': {'address': 'Händelstr. 51', 'lat': 50.93576906481016, 'lng': 6.937293920013939, 'labeledLatLngs': [{'label': 'display', 'lat': 50.93576906481016, 'lng': 6.937293920013939}], 'postalCode': '50674', 'cc': 'DE', 'city': 'Köln', 'state': 'Nordrhein-Westfalen', 'country': 'Deutschland', 'formattedAddress': ['Händelstr. 51', '50674 Köln', 'Deutschland']}, 'canonicalUrl': 'https://foursquare.com/v/kunstbruder/557ca611498ea86c7f1e1893', 'categories': [{'id': '52e81612bcbc57f1066b79f1', 'name': 'Bistro', 'pluralName': 'Bistros', 'shortName': 'Bistro', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d1e2931735', 'name': 'Art Gallery', 'pluralName': 'Art Galleries', 'shortName': 'Art Gallery', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_', 'suffix': '.png'}}, {'id': '52e81612bcbc57f1066b79f9', 'name': 'Modern European Restaurant', 'pluralName': 'Modern European Restaurants', 'shortName': 'Modern European', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 6}, 'url': 'https://www.kunstbruder.de', 'likes': {'count': 17, 'groups': [{'type': 'others', 'count': 17, 'items': []}], 'summary': '17 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.7, 'ratingColor': 'C5DE35', 'ratingSignals': 24, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'http://www.kunstbruder.de/restaurant/#menu', 'mobileUrl': 'http://www.kunstbruder.de/restaurant/#menu', 'externalUrl': 'http://www.kunstbruder.de/restaurant/#menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 11, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 11, 'items': [{'id': '5c6015a912f0a9002cc41c10', 'createdAt': 1549800873, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/97733900_bvXXyJnTw3EgEcBiikhnYl0twL4zyp8GFmVbyBkha3E.jpg', 'width': 1080, 'height': 1920, 'user': {'isSanctioned': False, 'firstName': 'Hbb', 'lastName': 'B', 'countryCode': 'IT'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'description': 'Kunstbruder ist ein Cross Culture Kitchen-Restaurant und eine Streetart-Galerie. Das internationale Streetfood genießt man in der Streetart-Galerie, in der unterschiedlichsten Künstlern Raum für urbane Kunst geboten wird. Kunstbruder dient auch als Location für Performances, Workshops u.v.m.', 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1434232337, 'tips': {'count': 6, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 6, 'items': [{'id': '5c60157d60255e002c12ab19', 'createdAt': 1549800829, 'text': 'Kunst und cafe zusammen', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5c60157d60255e002c12ab19', 'lang': 'de', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Hbb', 'lastName': 'B', 'countryCode': 'IT'}, 'authorInteractionType': 'meh'}]}]}, 'shortUrl': 'http://4sq.com/1FfuFtY', 'timeZone': 'Europe/Berlin', 'listed': {'count': 27, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 27, 'items': [{'id': '537dfd73498ecbd60a50af4d', 'name': 'Cologne Lunch', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Nils', 'countryCode': 'DE'}, 'editable': False, 'public': True, 'collab ...
# {'id': '5b1d6efaa30619002c440c7d', 'name': 'vevi - veganes vintage café', 'contact': {'phone': '+4922129856678', 'formattedPhone': '+49 221 29856678', 'instagram': 'vevi_cafe', 'facebook': '365004404016061', 'facebookUsername': 'vevi.cafe', 'facebookName': 'vevi - veganes Vintage Café'}, 'location': {'address': 'Brüsseler Str 29', 'lat': 50.93520340103255, 'lng': 6.934475898742676, 'labeledLatLngs': [{'label': 'display', 'lat': 50.93520340103255, 'lng': 6.934475898742676}], 'postalCode': '50674', 'cc': 'DE', 'neighborhood': 'Rathenauviertel', 'city': 'Köln', 'state': 'Nordrhein-Westfalen', 'country': 'Deutschland', 'formattedAddress': ['Brüsseler Str 29', '50674 Köln', 'Deutschland']}, 'canonicalUrl': 'https://foursquare.com/v/vevi--veganes-vintage-caf%C3%A9/5b1d6efaa30619002c440c7d', 'categories': [{'id': '4bf58dd8d48988d1d3941735', 'name': 'Vegetarian / Vegan Restaurant', 'pluralName': 'Vegetarian / Vegan Restaurants', 'shortName': 'Vegetarian / Vegan', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 4}, 'url': 'https://vevi-cafe.eatbu.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '€'}, 'likes': {'count': 8, 'groups': [{'type': 'others', 'count': 8, 'items': [{'isSanctioned': False, 'firstName': '@Monsieur.Clement', 'countryCode': 'DE'}, {'isSanctioned': False, 'firstName': 'Silvan', 'countryCode': 'DE'}, {'isSanctioned': False, 'firstName': 'Emre', 'lastName': 'V', 'countryCode': 'DE'}, {'isSanctioned': False, 'firstName': 'Florian', 'lastName': 'W', 'countryCode': 'NL'}]}], 'summary': '8 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.3, 'ratingColor': '73CF42', 'ratingSignals': 9, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 9, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 9, 'items': [{'id': '5d972ae677804e000821174e', 'createdAt': 1570188006, 'source': {'name': 'Swarm for Android', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/585636_Sml9D0DpIGmDiVHkKgTn7x6OyDxLkyJP7414zpiGhW8.jpg', 'width': 1900, 'height': 1425, 'user': {'isSanctioned': False, 'firstName': 'Mat', 'lastName': 'A', 'countryCode': 'GB'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1528655610, 'tips': {'count': 4, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 4, 'items': [{'id': '5da6dc37eb8e79000697c8b7', 'createdAt': 1571216439, 'text': 'Cozy vegan cafe with the most delicious cakes', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5da6dc37eb8e79000697c8b7', 'photo': {'id': '5da6dc37eb8e79000697c8b6', 'createdAt': 1571216439, 'source': {'name': 'Swarm for Android', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/585636_k6kVHxyzSXzz_4YzADkZSVBJErF52zqKK2A9wYDUaIg.jpg', 'width': 1900, 'height': 1425, 'visibility': 'public'}, 'photourl': 'https://fastly.4sqi.net/img/general/original/585636_k6kVHxyzSXzz_4YzADkZSVBJErF52zqKK2A9wYDUaIg.jpg', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Mat', 'lastName': 'A', 'countryCode': 'GB'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'https://4sq.com/2JquJWy', 'timeZone': 'Europe/Berlin', 'listed': {'count': 16, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 16, 'items': [{'id': '57096c6a498e28e0649c165c', 'name': "To Do's @ KÖLN", 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Sarah', 'lastName': 'T', 'countryCode': 'DE'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/153440566/list/to-dos--k%C3%B6ln', ...
# 2
# [['5b1d6efaa30619002c440c7d', 'vevi - veganes vintage café', 2, 8.3]]
# {'id': '592c0778029a5545daf45222', 'name': 'Mashery - Hummus Kitchen', 'contact': {'instagram': 'masheryhummuskitchen', 'facebook': '1572989502964937', 'facebookUsername': 'masheryhummus', 'facebookName': 'Mashery - Hummus Kitchen'}, 'location': {'address': 'Roonstr. 36', 'lat': 50.93117059048177, 'lng': 6.937650702334529, 'labeledLatLngs': [{'label': 'display', 'lat': 50.93117059048177, 'lng': 6.937650702334529}], 'postalCode': '50674', 'cc': 'DE', 'neighborhood': 'Rathenauviertel', 'city': 'Köln', 'state': 'Nordrhein-Westfalen', 'country': 'Deutschland', 'formattedAddress': ['Roonstr. 36', '50674 Köln', 'Deutschland']}, 'canonicalUrl': 'https://foursquare.com/v/mashery--hummus-kitchen/592c0778029a5545daf45222', 'categories': [{'id': '56aa371be4b08b9a8d573529', 'name': 'Israeli Restaurant', 'pluralName': 'Israeli Restaurants', 'shortName': 'Israeli', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/falafel_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d1d3941735', 'name': 'Vegetarian / Vegan Restaurant', 'pluralName': 'Vegetarian / Vegan Restaurants', 'shortName': 'Vegetarian / Vegan', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 11}, 'url': 'http://www.mashery-hummus.de', 'likes': {'count': 34, 'groups': [{'type': 'others', 'count': 34, 'items': []}], 'summary': '34 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.6, 'ratingColor': '73CF42', 'ratingSignals': 45, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 23, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 23, 'items': [{'id': '5c70390b95d986002c523aee', 'createdAt': 1550858507, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/3989879_wcmquPh30jr1wNOrnQ_Q2eC8SECuHI9i-yl44LEC8nc.jpg', 'width': 1440, 'height': 1920, 'user': {'isSanctioned': False, 'firstName': 'Jan', 'lastName': 'B', 'countryCode': 'DE'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1496057720, 'tips': {'count': 11, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 11, 'items': [{'id': '5d48903d8885780007db2b58', 'createdAt': 1565036605, 'text': 'Spitzen Restaurant. Klein, schick, nettes Personal. Hummus ist der Hammer und ach die Falafel sind sehr gut.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5d48903d8885780007db2b58', 'lang': 'de', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Andre', 'lastName': 'S', 'countryCode': 'DE'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/2qrLBm8', 'timeZone': 'Europe/Berlin', 'listed': {'count': 84, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 84, 'items': [{'id': '566c311d498e06920a405583', 'name': 'Germany', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Taygun', 'lastName': 'T', 'countryCode': 'TR'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/7181861/list/germany', 'canonicalUrl': 'https://foursquare.com/user/7181861/list/germany', 'createdAt': 1449931037, 'updatedAt': 1604601658, 'followers': {'count': 2}, 'listItems': {'count': 199, 'items': [{'id': 'v592c0778029a5545daf45222', 'createdAt': 1572187917}]}}, {'id': '5b2a7f07646e38002cdb8a74', 'name': 'Köln', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Peroni', 'lastName': 'M', 'countryCode': 'DE'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/grosserperoni/list/ ...
# {'id': '4d94c3833048b1f73eed3864', 'name': 'Gate to India', 'contact': {}, 'location': {'address': 'Engelbertstr. 17', 'lat': 50.931450195204945, 'lng': 6.9389991668356705, 'labeledLatLngs': [{'label': 'display', 'lat': 50.931450195204945, 'lng': 6.9389991668356705}], 'postalCode': '50674', 'cc': 'DE', 'city': 'Köln', 'state': 'Nordrhein-Westfalen', 'country': 'Deutschland', 'formattedAddress': ['Engelbertstr. 17', '50674 Köln', 'Deutschland']}, 'canonicalUrl': 'https://foursquare.com/v/gate-to-india/4d94c3833048b1f73eed3864', 'categories': [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 1}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '€'}, 'likes': {'count': 7, 'groups': [{'type': 'others', 'count': 7, 'items': [{'isSanctioned': False, 'firstName': 'Cris', 'lastName': 'A', 'countryCode': 'DE'}, {'isSanctioned': False, 'firstName': 'Jessi', 'lastName': 'L', 'countryCode': 'BE'}, {'isSanctioned': False, 'firstName': 'Cemil', 'lastName': 'T', 'countryCode': 'DE'}, {'isSanctioned': False, 'firstName': 'Cemil', 'lastName': 'T', 'countryCode': 'DE'}]}], 'summary': '7 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.1, 'ratingColor': 'C5DE35', 'ratingSignals': 10, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 11, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 11, 'items': [{'id': '58c4646eac136968ac999644', 'createdAt': 1489265774, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/37273248_6TDD7t7UQyFGTc4YYqg8MtjTxks20gBcUyupjYQ4yO0.jpg', 'width': 1920, 'height': 1440, 'user': {'isSanctioned': False, 'firstName': 'Cemil', 'lastName': 'T', 'countryCode': 'DE'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1301595011, 'tips': {'count': 1, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 1, 'items': [{'id': '5410a160498ed2286e49c3bd', 'createdAt': 1410376032, 'text': 'Supertolles Restaurant empfehle jeden hier vorbei zu kommen,der Chicken Tikka Masalla ein Muss !!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5410a160498ed2286e49c3bd', 'lang': 'de', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Cemil', 'lastName': 'T', 'countryCode': 'DE'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/fVQMib', 'timeZone': 'Europe/Berlin', 'listed': {'count': 11, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 11, 'items': [{'id': '4eb9a56fbe7b7abd0fed7b30', 'name': 'Indische Restaurants in Köln', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Riccardo', 'lastName': 'G', 'countryCode': 'MY'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/riccgia/list/indische-restaurants-in-k%C3%B6ln', 'canonicalUrl': 'https://foursquare.com/riccgia/list/indische-restaurants-in-k%C3%B6ln', 'createdAt': 1320789359, 'updatedAt': 1366488326, 'followers': {'count': 1}, 'listItems': {'count': 7, 'items': [{'id': 'v4d94c3833048b1f73eed3864', 'createdAt': 1320789453}]}}, {'id': '5633838c498e324c6130e1ed', 'name': 'Köln', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Eric', 'countryCode': 'DE'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/impulsivlyurban/list/k%C3%B6ln', 'canonicalUrl': 'https://foursquare.com/impulsivlyurban/list/k%C3%B6ln', 'createdAt': 1446216588, 'updatedAt': 1505926501, 'followers': {'count' ...
# 2
# [['4d94c3833048b1f73eed3864', 'Gate to India', 2, 7.1]]
# {'id': '52861309498eb1a0d3bb4b45', 'name': 'Bonjour Saigon', 'contact': {'phone': '+4922125850888', 'formattedPhone': '+49 221 25850888', 'twitter': 'bonjoursaigon'}, 'location': {'address': 'Richard-Wagner-Str. 24', 'crossStreet': 'Brüsseler Str.', 'lat': 50.93550322033644, 'lng': 6.934440565133471, 'labeledLatLngs': [{'label': 'display', 'lat': 50.93550322033644, 'lng': 6.934440565133471}], 'postalCode': '50674', 'cc': 'DE', 'city': 'Köln', 'state': 'Nordrhein-Westfalen', 'country': 'Deutschland', 'formattedAddress': ['Richard-Wagner-Str. 24 (Brüsseler Str.)', '50674 Köln', 'Deutschland']}, 'canonicalUrl': 'https://foursquare.com/v/bonjour-saigon/52861309498eb1a0d3bb4b45', 'categories': [{'id': '4bf58dd8d48988d14a941735', 'name': 'Vietnamese Restaurant', 'pluralName': 'Vietnamese Restaurants', 'shortName': 'Vietnamese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 18}, 'url': 'http://www.bonjoursaigon.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '€'}, 'likes': {'count': 58, 'groups': [{'type': 'others', 'count': 58, 'items': []}], 'summary': '58 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.7, 'ratingColor': 'C5DE35', 'ratingSignals': 86, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 26, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 26, 'items': [{'id': '530ce491498e6b61775a2f8c', 'createdAt': 1393353873, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/33248470_NA7Np5cRpPSTZDqLPm4503PI8xKPv14_iZh5KuWP3L4.jpg', 'width': 959, 'height': 354, 'user': {'isSanctioned': False, 'firstName': 'Oli', 'lastName': 'V', 'countryCode': 'DE'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1384518409, 'tips': {'count': 18, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 18, 'items': [{'id': '54398b97498e5e36657563e5', 'createdAt': 1413057431, 'text': 'Great dishes, super dessert:)', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/54398b97498e5e36657563e5', 'lang': 'en', 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': []}], 'summary': '1 like'}, 'logView': True, 'agreeCount': 1, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Arvid', 'lastName': 'S', 'countryCode': 'CA'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/18zR3zf', 'timeZone': 'Europe/Berlin', 'listed': {'count': 30, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 30, 'items': [{'id': '537dfd73498ecbd60a50af4d', 'name': 'Cologne Lunch', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Nils', 'countryCode': 'DE'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/6664348/list/cologne-lunch', 'canonicalUrl': 'https://foursquare.com/user/6664348/list/cologne-lunch', 'createdAt': 1400765811, 'updatedAt': 1490545634, 'photo': {'id': '51041d7fe4b081fc42608305', 'createdAt': 1359224191, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/4958501_3D-hKdEpbZJLFZKYb75MgQx3T87IRV5n3TrA02P70Ng.jpg', 'width': 720, 'height': 960, 'user': {'isSanctioned': False, 'firstName': 'Stefanie', 'countryCode': 'DE'}, 'visibility': 'public'}, 'followers': {'count': 4}, 'listItems': {'count': 91, 'items': [{'id': 'v52861309498eb1a0d3bb4b45', 'createdAt': 1456059042}]}}, {'id': '58d02fd09c439d2ce02a1e40', 'name': 'Asiatisch', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Sandra', 'lastName': 'W', ' ...
# 2
# [['52861309498eb1a0d3bb4b45', 'Bonjour Saigon', 2, 7.7]]
# ...
# 1
# [['4b51dd7ff964a5209a5827e3', 'Zülpicher Döner', 1, 7.4]]
# {'id': '4bd86d4f0b779c74a41e07a0', 'name': 'Il Bagutta', 'contact': {'phone': '+49221212694', 'formattedPhone': '+49 221 212694', 'instagram': 'il_bagutta', 'facebook': '664026283633946', 'facebookUsername': 'ilbagutta', 'facebookName': 'Il bagutta'}, 'location': {'address': 'Heinsbergstr. 20a', 'lat': 50.929980601565426, 'lng': 6.938212705173249, 'labeledLatLngs': [{'label': 'display', 'lat': 50.929980601565426, 'lng': 6.938212705173249}], 'postalCode': '50674', 'cc': 'DE', 'city': 'Köln', 'state': 'Nordrhein-Westfalen', 'country': 'Deutschland', 'formattedAddress': ['Heinsbergstr. 20a', '50674 Köln', 'Deutschland']}, 'canonicalUrl': 'https://foursquare.com/v/il-bagutta/4bd86d4f0b779c74a41e07a0', 'categories': [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 26}, 'url': 'http://www.ilbagutta.de', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '€'}, 'likes': {'count': 52, 'groups': [{'type': 'others', 'count': 52, 'items': []}], 'summary': '52 Likes'}, 'dislike': False, 'ok': False, 'rating': 9.0, 'ratingColor': '00B551', 'ratingSignals': 78, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 48, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 48, 'items': [{'id': '4f81bdfee4b0e533ad910f68', 'createdAt': 1333902846, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/YUNgTsvy3k9vD1m7PdUyQlLwV-FCby_cyr9JqX3-hv8.jpg', 'width': 720, 'height': 540, 'user': {'isSanctioned': False, 'firstName': 'Mohamad Faizal', 'lastName': 'B', 'countryCode': 'MY'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1272474959, 'tips': {'count': 26, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 26, 'items': [{'id': '4ea479bd0aaf711181778f63', 'createdAt': 1319401917, 'text': 'No idea which idiot labelled this place "Imbiss". In fact, it\'s avery nice Brasserie, with fresh and homemade food. Decent prices, nice atmosphere.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4ea479bd0aaf711181778f63', 'lang': 'en', 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': [{'isSanctioned': False, 'firstName': 'Laura', 'countryCode': 'LU'}]}], 'summary': '1 like'}, 'logView': True, 'agreeCount': 1, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Angie', 'lastName': 'R', 'countryCode': 'DE'}}]}]}, 'shortUrl': 'http://4sq.com/97Sgq2', 'timeZone': 'Europe/Berlin', 'listed': {'count': 89, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 89, 'items': [{'id': '4ea468e6f9f48bb22d9407f5', 'name': 'Best places in Köln, Deutschland', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Angie', 'lastName': 'R', 'countryCode': 'DE'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/ichweisswo/list/best-places-in-k%C3%B6ln-deutschland', 'canonicalUrl': 'https://foursquare.com/ichweisswo/list/best-places-in-k%C3%B6ln-deutschland', 'createdAt': 1319397606, 'updatedAt': 1348522272, 'followers': {'count': 14}, 'listItems': {'count': 11, 'items': [{'id': 't4ea479bd0aaf711181778f63', 'createdAt': 1319401830}]}}, {'id': '50005738e4b0c955574a94bb', 'name': 'ESSEN', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Steve', 'countryCode': 'DE'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/32158079/lis ...
# 2
# [['4bd86d4f0b779c74a41e07a0', 'Il Bagutta', 2, 9.0]]
# {'id': '4e5635e9d22dd2065dc3b33e', 'name': 'Lu Vietnamese Cuisine', 'contact': {'phone': '+4922154813457', 'formattedPhone': '+49 221 54813457', 'instagram': 'luvietnamesecuisine', 'facebook': '115364945219819', 'facebookUsername': 'luvietnamesecuisine', 'facebookName': 'LU-vietnamese Cuisine'}, 'location': {'address': 'Hohenstaufenring 21', 'lat': 50.930555435988246, 'lng': 6.940864575286754, 'labeledLatLngs': [{'label': 'display', 'lat': 50.930555435988246, 'lng': 6.940864575286754}], 'postalCode': '50674', 'cc': 'DE', 'city': 'Köln', 'state': 'Nordrhein-Westfalen', 'country': 'Deutschland', 'formattedAddress': ['Hohenstaufenring 21', '50674 Köln', 'Deutschland']}, 'canonicalUrl': 'https://foursquare.com/v/lu-vietnamese-cuisine/4e5635e9d22dd2065dc3b33e', 'categories': [{'id': '4bf58dd8d48988d14a941735', 'name': 'Vietnamese Restaurant', 'pluralName': 'Vietnamese Restaurants', 'shortName': 'Vietnamese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 52}, 'url': 'http://www.lokal-lu.de', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '€'}, 'likes': {'count': 144, 'groups': [{'type': 'others', 'count': 144, 'items': []}], 'summary': '144 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.6, 'ratingColor': '73CF42', 'ratingSignals': 199, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'http://www.lokal-lu.de/#Speisekarte', 'mobileUrl': 'http://www.lokal-lu.de/#Speisekarte', 'externalUrl': 'http://www.lokal-lu.de/#Speisekarte'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 97, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 97, 'items': [{'id': '4feef26be4b02af6a22b2913', 'createdAt': 1341059691, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/Do0_sQRgk2gP36d4uim6liMoPyn9iPzSSnwvUCUzndk.jpg', 'width': 540, 'height': 720, 'user': {'isSanctioned': False, 'firstName': 'Robert', 'countryCode': 'DE'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1314272745, 'tips': {'count': 52, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 52, 'items': [{'id': '53e33bcb498e0886a55090ed', 'createdAt': 1407400907, 'text': 'Extrem lecker. Alle Gerichte auf der Tageskarte gibt es auf Wunsch auch vegetarisch (der Tofu ist ein Traum). Sehr zu empfehlen sind die selbstgemachten "Juices" mit Maracuja oder Limette!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/53e33bcb498e0886a55090ed', 'photo': {'id': '53e33bcd498e54af1575ec79', 'createdAt': 1407400909, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/1440979_MMybARJkoKEiZYTPccqh1RJ932WEY-qYjjVcYptcBy0.jpg', 'width': 960, 'height': 720, 'visibility': 'public'}, 'photourl': 'https://fastly.4sqi.net/img/general/original/1440979_MMybARJkoKEiZYTPccqh1RJ932WEY-qYjjVcYptcBy0.jpg', 'lang': 'de', 'likes': {'count': 4, 'groups': [{'type': 'others', 'count': 4, 'items': [{'isSanctioned': False, 'firstName': 'Björn', 'lastName': 'G', 'countryCode': 'DE'}, {'isSanctioned': False, 'firstName': 'Tobias', 'lastName': 'K', 'countryCode': 'DE'}, {'isSanctioned': False, 'firstName': 'Maurice', 'lastName': 'G', 'countryCode': 'DE'}, {'isSanctioned': False, 'firstName': 'Thorsten', 'lastName': 'S', 'countryCode': 'DE'}]}], 'summary': '4 likes'}, 'logView': True, 'agreeCount': 4, 'disagreeCount': 0, 'todo': {'count': 1}, 'user': {'isSanctioned': False, 'firstName': 'Christina', 'countryCode': 'DE'}, 'authorInterac ...
# 2
# [['4e5635e9d22dd2065dc3b33e', 'Lu Vietnamese Cuisine', 2, 8.6]]
# {'id': '4bfb878c8f32ef3b6a1d05aa', 'name': 'Al Salam', 'contact': {'phone': '+492212019882', 'formattedPhone': '+49 221 2019882', 'instagram': 'alsalam_de', 'facebook': '113799066272', 'facebookUsername': 'alsalam.de', 'facebookName': 'Al-Salam Orient Lounge & Esskultur'}, 'location': {'address': 'Hohenstaufenring 22', 'lat': 50.930673618461356, 'lng': 6.941128687861134, 'labeledLatLngs': [{'label': 'display', 'lat': 50.930673618461356, 'lng': 6.941128687861134}], 'postalCode': '50674', 'cc': 'DE', 'city': 'Köln', 'state': 'Nordrhein-Westfalen', 'country': 'Deutschland', 'formattedAddress': ['Hohenstaufenring 22', '50674 Köln', 'Deutschland']}, 'canonicalUrl': 'https://foursquare.com/v/al-salam/4bfb878c8f32ef3b6a1d05aa', 'categories': [{'id': '4bf58dd8d48988d115941735', 'name': 'Middle Eastern Restaurant', 'pluralName': 'Middle Eastern Restaurants', 'shortName': 'Middle Eastern', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 16}, 'url': 'https://www.al-salam.de', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '€'}, 'likes': {'count': 36, 'groups': [{'type': 'others', 'count': 36, 'items': []}], 'summary': '36 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.5, 'ratingColor': '73CF42', 'ratingSignals': 53, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://www.al-salam.de/de/speisekarte/', 'mobileUrl': 'https://www.al-salam.de/de/speisekarte/', 'externalUrl': 'https://www.al-salam.de/de/speisekarte/'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 14, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 14, 'items': [{'id': '5f443c93dc34a376370f88b8', 'createdAt': 1598307475, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/40009139_9Jop3dsvH5BCO6XQowwuaruFD-rVPiabPiG6YiIamfU.jpg', 'width': 1920, 'height': 1440, 'user': {'isSanctioned': False, 'firstName': '@Monsieur.Clement', 'countryCode': 'DE'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1274775436, 'tips': {'count': 16, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 16, 'items': [{'id': '55070081498e590f174d4ab7', 'createdAt': 1426522241, 'text': 'Superleckeres Essen  mit vielen neuen, orientalischen Geschmackserlebnissen...toller, freundlicher Service und eine nette Atmosphäre!Lohnt sich auf jeden Fall wenn man mal was neues ausprobieren will!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/55070081498e590f174d4ab7', 'lang': 'de', 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': [{'isSanctioned': False, 'firstName': 'Charlotte', 'lastName': 'W', 'countryCode': 'SE'}]}], 'summary': '1 like'}, 'logView': True, 'agreeCount': 4, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'isSanctioned': False, 'firstName': 'Theresa', 'lastName': 'W', 'countryCode': 'IT'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/aYpG6t', 'timeZone': 'Europe/Berlin', 'listed': {'count': 53, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 53, 'items': [{'id': '4eac3b39d3e3846cbd6a703d', 'name': 'Best Bars in Köln', 'description': '', 'type': 'others', 'user': {'isSanctioned': False, 'firstName': 'Riccardo', 'lastName': 'G', 'countryCode': 'MY'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/riccgia/list/best-bars-in-k%C3%B6ln', 'canonicalUrl': 'https://foursquare.com/riccgia/list/best-bars-in-k%C3%B6ln', 'createdAt': 1319910201, 'updatedAt': 1425467770, 'followers': {'count': 37}, 'listItems' ...
# 2
# [['4bfb878c8f32ef3b6a1d05aa', 'Al Salam', 2, 8.5]]

# %% [markdown]
# Now we merge the venue list with the respective venue details.

# %%
#dfObj
#plz_venues
score_venues = pd.merge(plz_venues, dfObj, on='ID')
score_venues
# Out:
#                           ID                       Name_x  \
# 0   5c084427061b51002c127368                  Tapeo & Co.
# 1   57645427498e7a5746a35766                       Tanica
# 2   5a3a15691f8ed64718884d30                   Tigermilch
# 3   583ec82c19b1ad33a488ae04                       mikoto
# 4   4b05886bf964a52082c422e3                  Café Wahlen
# 5   5b1d6efaa30619002c440c7d  vevi - veganes vintage café
# 6   4d94c3833048b1f73eed3864                Gate to India
# 7   52861309498eb1a0d3bb4b45               Bonjour Saigon
# 8   4fdf9403e4b0a1e6c282807d                       Alborz
# 9   4b31415ef964a520590325e3                Fischermanns'
# 10  54d7540d498ed907b5f12ed4                      Bangkok
# 11  4b1812f5f964a52090cc23e3            Weinstube Bacchus
# 12  4b05886ff964a520e9c522e3                      El Inca
# 13  51d506fe498e56324b31353c        Gernys Schnelleinkauf
# 14  4bc748f714d79521581067e9                      Amabile
# 15  4b05886af964a52045c422e3                      Orlando
# 16  4bca0278fb84c9b60e261c3e                Beef Brothers
# 17  56856215498e1315b40f52e8                    El Gaucho
# 18  4b77f392f964a520ebaf2ee3                 Die Rösterei
# 19  4b058869f964a5202ec422e3                Café Feynsinn
# 20  4b16508cf964a52028b823e3                Salon Schmitz
# 21  5c8534802f97ec002c452f33                 Little Nonna
# 22  4b38eea9f964a5207f5225e3                       Ni Hao
# 23  53909493498e036846709104                     Bibimbab
# 24  53d8b221498e6bfb238e7ba8                 Kaffee Krema
# 25  58f8e093c21cb17ce76769d7                       Sonder
# 26  4ba20b35f964a52001d837e3       Meister Gerhard no 008
# 27  4bd1fd099854d13a8ab1fa4d                  Warung Bayu
# 28  4bf56d296a31d13a7dde962e       Reissdorf am Hahnentor
# 29  4b0e556ff964a520e35623e3                     cafecafe
# 30  4b51dd7ff964a5209a5827e3              Zülpicher Döner
# 31  4bd86d4f0b779c74a41e07a0                   Il Bagutta
# 32  4e5635e9d22dd2065dc3b33e        Lu Vietnamese Cuisine
# 33  4bfb878c8f32ef3b6a1d05aa                     Al Salam
#
#                          Category  Distance PostalCode  \
# 0                Tapas Restaurant        81      50674
# 1              Italian Restaurant       142      50674
# 2             Peruvian Restaurant       176      50674
# 3                Sushi Restaurant       196      59674
# 4                            Café       206      50674
# 5   Vegetarian / Vegan Restaurant       254      50674
# 6               Indian Restaurant       274      50674
# 7           Vietnamese Restaurant       280      50674
# 8       Middle Eastern Restaurant       280      50674
# 9                      Restaurant       285      50674
# 10                Thai Restaurant       285      50674
# 11              German Restaurant       291      50674
# 12            Peruvian Restaurant       294      50674
# 13                     Soup Place       296      50676
# 14              French Restaurant       298      50674
# 15                           Café       316      50764
# 16                   Burger Joint       321      50674
# 17                     Steakhouse       324      50674
# 18                           Café       325      50674
# 19                           Café       329      50674
# 20                           Café       335      50674
# 21             Italian Restaurant       339      50674
# 22             Chinese Restaurant       342      50674
# 23              Korean Restaurant       348      50674
# 24                           Café       348      50674
# 25              German Restaurant       352      50674
# 26               Tapas Restaurant       357      50674
# 27          Indonesian Restaurant       363      50674
# 28              German Restaurant       389      50674
# 29                           Café       401      50674
# 30             Turkish Restaurant       409      50674
# 31             Italian Restaurant       409      50674
# 32          Vietnamese Restaurant       430      50674
# 33      Middle Eastern Restaurant       432      50674
#
#                    Address                       Name_y Price  Rating
# 0            Lindenstr. 38                  Tapeo & Co.     1     8.0
# 1       Engelbertstraße 31                       Tanica     2     8.1
# 2        Brüsseler Str. 12                   Tigermilch     1     7.0
# 3      Hohenstaufenring 55                       mikoto     1     8.6
# 4      Hohenstaufenring 64                  Café Wahlen     2     8.2
# 5         Brüsseler Str 29  vevi - veganes vintage café     2     8.3
# 6         Engelbertstr. 17                Gate to India     2     7.1
# 7   Richard-Wagner-Str. 24               Bonjour Saigon     2     7.7
# 8          Rathenauplatz 1                       Alborz     2     8.3
# 9         Rathenauplatz 21                Fischermanns'     1     7.6
# 10         Lindenstraße 81                      Bangkok     1     8.2
# 11        Rathenauplatz 17            Weinstube Bacchus     2     6.9
# 12            Görresstr. 2                      El Inca     1     8.2
# 13      Schaafenstr. 53-55        Gernys Schnelleinkauf     1     7.9
# 14            Görresstr. 2                      Amabile     2     7.7
# 15         Engelbertstr. 9                      Orlando     1     8.6
# 16        Aachener Str. 12                Beef Brothers     2     8.4
# 17  Hohenstaufenring 29-37                    El Gaucho     2     8.5
# 18        Aachener Str. 22                 Die Rösterei     2     8.3
# 19         Rathenauplatz 7                Café Feynsinn     1     7.8
# 20        Aachener Str. 28                Salon Schmitz     2     7.9
# 21        Brabanter Str. 1                 Little Nonna     2     8.2
# 22       Brüsseler Str. 44                       Ni Hao     2     8.3
# 23     Hohenstaufenring 23                     Bibimbab     2     7.5
# 24        Aachener Str. 10                 Kaffee Krema     1     7.4
# 25           Lindenstr. 93                       Sonder     2     8.5
# 26         Rathenauplatz 8       Meister Gerhard no 008     1     8.8
# 27        Brabanter Str. 5                  Warung Bayu     2     8.0
# 28           Hahnenstr. 24       Reissdorf am Hahnentor     2     7.1
# 29        Aachener Str. 45                     cafecafe     1     8.3
# 30        Zülpicher Str. 3              Zülpicher Döner     1     7.4
# 31       Heinsbergstr. 20a                   Il Bagutta     2     9.0
# 32     Hohenstaufenring 21        Lu Vietnamese Cuisine     2     8.6
# 33     Hohenstaufenring 22                     Al Salam     2     8.5

# %%
score_venues2 = score_venues.astype({"Price": int})

# %%
max_dist = score_venues2["Distance"].max()
max_rating = score_venues2["Rating"].max()
max_price = score_venues2["Price"].max()
max_price
# Out:
# 2

# %% [markdown]
# Create a new column containing the calculated score

# %%
score_venues2["Score"] = (1-(score_venues2["Distance"]/max_dist))*0.15 + score_venues2["Rating"]/max_rating*0.7 + (1-score_venues2["Price"]/max_price)*0.15
score_venues2.sort_values(by=['Score'], ascending=False)
# Out:
#                           ID                       Name_x  \
# 3   583ec82c19b1ad33a488ae04                       mikoto
# 0   5c084427061b51002c127368                  Tapeo & Co.
# 26  4ba20b35f964a52001d837e3       Meister Gerhard no 008
# 15  4b05886af964a52045c422e3                      Orlando
# 10  54d7540d498ed907b5f12ed4                      Bangkok
# 12  4b05886ff964a520e9c522e3                      El Inca
# 13  51d506fe498e56324b31353c        Gernys Schnelleinkauf
# 29  4b0e556ff964a520e35623e3                     cafecafe
# 1   57645427498e7a5746a35766                       Tanica
# 19  4b058869f964a5202ec422e3                Café Feynsinn
# 9   4b31415ef964a520590325e3                Fischermanns'
# 4   4b05886bf964a52082c422e3                  Café Wahlen
# 2   5a3a15691f8ed64718884d30                   Tigermilch
# 31  4bd86d4f0b779c74a41e07a0                   Il Bagutta
# 5   5b1d6efaa30619002c440c7d  vevi - veganes vintage café
# 17  56856215498e1315b40f52e8                    El Gaucho
# 8   4fdf9403e4b0a1e6c282807d                       Alborz
# 16  4bca0278fb84c9b60e261c3e                Beef Brothers
# 25  58f8e093c21cb17ce76769d7                       Sonder
# 18  4b77f392f964a520ebaf2ee3                 Die Rösterei
# 24  53d8b221498e6bfb238e7ba8                 Kaffee Krema
# 22  4b38eea9f964a5207f5225e3                       Ni Hao
# 21  5c8534802f97ec002c452f33                 Little Nonna
# 32  4e5635e9d22dd2065dc3b33e        Lu Vietnamese Cuisine
# 33  4bfb878c8f32ef3b6a1d05aa                     Al Salam
# 30  4b51dd7ff964a5209a5827e3              Zülpicher Döner
# 7   52861309498eb1a0d3bb4b45               Bonjour Saigon
# 20  4b16508cf964a52028b823e3                Salon Schmitz
# 27  4bd1fd099854d13a8ab1fa4d                  Warung Bayu
# 14  4bc748f714d79521581067e9                      Amabile
# 23  53909493498e036846709104                     Bibimbab
# 6   4d94c3833048b1f73eed3864                Gate to India
# 11  4b1812f5f964a52090cc23e3            Weinstube Bacchus
# 28  4bf56d296a31d13a7dde962e       Reissdorf am Hahnentor
#
#                          Category  Distance PostalCode  \
# 3                Sushi Restaurant       196      59674
# 0                Tapas Restaurant        81      50674
# 26               Tapas Restaurant       357      50674
# 15                           Café       316      50764
# 10                Thai Restaurant       285      50674
# 12            Peruvian Restaurant       294      50674
# 13                     Soup Place       296      50676
# 29                           Café       401      50674
# 1              Italian Restaurant       142      50674
# 19                           Café       329      50674
# 9                      Restaurant       285      50674
# 4                            Café       206      50674
# 2             Peruvian Restaurant       176      50674
# 31             Italian Restaurant       409      50674
# 5   Vegetarian / Vegan Restaurant       254      50674
# 17                     Steakhouse       324      50674
# 8       Middle Eastern Restaurant       280      50674
# 16                   Burger Joint       321      50674
# 25              German Restaurant       352      50674
# 18                           Café       325      50674
# 24                           Café       348      50674
# 22             Chinese Restaurant       342      50674
# 21             Italian Restaurant       339      50674
# 32          Vietnamese Restaurant       430      50674
# 33      Middle Eastern Restaurant       432      50674
# 30             Turkish Restaurant       409      50674
# 7           Vietnamese Restaurant       280      50674
# 20                           Café       335      50674
# 27          Indonesian Restaurant       363      50674
# 14              French Restaurant       298      50674
# 23              Korean Restaurant       348      50674
# 6               Indian Restaurant       274      50674
# 11              German Restaurant       291      50674
# 28              German Restaurant       389      50674
#
#                    Address                       Name_y  Price  Rating  \
# 3      Hohenstaufenring 55                       mikoto      1     8.6
# 0            Lindenstr. 38                  Tapeo & Co.      1     8.0
# 26         Rathenauplatz 8       Meister Gerhard no 008      1     8.8
# 15         Engelbertstr. 9                      Orlando      1     8.6
# 10         Lindenstraße 81                      Bangkok      1     8.2
# 12            Görresstr. 2                      El Inca      1     8.2
# 13      Schaafenstr. 53-55        Gernys Schnelleinkauf      1     7.9
# 29        Aachener Str. 45                     cafecafe      1     8.3
# 1       Engelbertstraße 31                       Tanica      2     8.1
# 19         Rathenauplatz 7                Café Feynsinn      1     7.8
# 9         Rathenauplatz 21                Fischermanns'      1     7.6
# 4      Hohenstaufenring 64                  Café Wahlen      2     8.2
# 2        Brüsseler Str. 12                   Tigermilch      1     7.0
# 31       Heinsbergstr. 20a                   Il Bagutta      2     9.0
# 5         Brüsseler Str 29  vevi - veganes vintage café      2     8.3
# 17  Hohenstaufenring 29-37                    El Gaucho      2     8.5
# 8          Rathenauplatz 1                       Alborz      2     8.3
# 16        Aachener Str. 12                Beef Brothers      2     8.4
# 25           Lindenstr. 93                       Sonder      2     8.5
# 18        Aachener Str. 22                 Die Rösterei      2     8.3
# 24        Aachener Str. 10                 Kaffee Krema      1     7.4
# 22       Brüsseler Str. 44                       Ni Hao      2     8.3
# 21        Brabanter Str. 1                 Little Nonna      2     8.2
# 32     Hohenstaufenring 21        Lu Vietnamese Cuisine      2     8.6
# 33     Hohenstaufenring 22                     Al Salam      2     8.5
# 30        Zülpicher Str. 3              Zülpicher Döner      1     7.4
# 7   Richard-Wagner-Str. 24               Bonjour Saigon      2     7.7
# 20        Aachener Str. 28                Salon Schmitz      2     7.9
# 27        Brabanter Str. 5                  Warung Bayu      2     8.0
# 14            Görresstr. 2                      Amabile      2     7.7
# 23     Hohenstaufenring 23                     Bibimbab      2     7.5
# 6         Engelbertstr. 17                Gate to India      2     7.1
# 11        Rathenauplatz 17            Weinstube Bacchus      2     6.9
# 28           Hahnenstr. 24       Reissdorf am Hahnentor      2     7.1
#
#        Score
# 3   0.825833
# 0   0.819097
# 26  0.785486
# 15  0.784167
# 10  0.763819
# 12  0.760694
# 13  0.736667
# 29  0.731319
# 1   0.730694
# 19  0.717431
# 9   0.717153
# 4   0.716250
# 2   0.708333
# 31  0.707986
# 5   0.707361
# 17  0.698611
# 8   0.698333
# 16  0.691875
# 25  0.688889
# 18  0.682708
# 24  0.679722
# 22  0.676806
# 21  0.670069
# 32  0.669583
# 33  0.661111
# 30  0.658542
# 7   0.651667
# 20  0.648125
# 27  0.646181
# 14  0.645417
# 23  0.612500
# 6   0.607083
# 11  0.585625
# 28  0.567153

# %%
(1-score_venues2["Rating"]/max_rating)
# Out:
# 0     0.111111
# 1     0.100000
# 2     0.222222
# 3     0.044444
# 4     0.088889
# 5     0.077778
# 6     0.211111
# 7     0.144444
# 8     0.077778
# 9     0.155556
# 10    0.088889
# 11    0.233333
# 12    0.088889
# 13    0.122222
# 14    0.144444
# 15    0.044444
# 16    0.066667
# 17    0.055556
# 18    0.077778
# 19    0.133333
# 20    0.122222
# 21    0.088889
# 22    0.077778
# 23    0.166667
# 24    0.177778
# 25    0.055556
# 26    0.022222
# 27    0.111111
# 28    0.211111
# 29    0.077778
# 30    0.177778
# 31    0.000000
# 32    0.044444
# 33    0.055556
# Name: Rating, dtype: float64

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in df_food.columns if col.startswith('location.')] + ['id']
dataframe_filtered = df_food.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)
#filter only category restaurant


# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.drop(columns = ["labeledLatLngs", "formattedAddress"], inplace = True)
dataframe_filtered[dataframe_filtered["categories"].str.contains("Restaurant", na = False)]
dataframe_filtered
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-d297cd70e2e2> in <module>
#       1 # keep only columns that include venue name, and anything that is associated with location
# ----> 2 filtered_columns = ['name', 'categories'] + [col for col in df_food.columns if col.startswith('location.')] + ['id']
#       3 dataframe_filtered = df_food.loc[:, filtered_columns]
#       4
#       5 # function that extracts the category of the venue
#
# NameError: name 'df_food' is not defined

# %%
cologne_onehot = pd.get_dummies(plz_venues[['Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
cologne_onehot['PostalCode'] = plz_venues['PostalCode'] 

# move neighborhood column to the first column
fixed_columns = [cologne_onehot.columns[-1]] + list(cologne_onehot.columns[:-1])
cologne_onehot = cologne_onehot[fixed_columns]
cologne_grouped = cologne_onehot.groupby('PostalCode').mean().reset_index()
cologne_grouped.head()

# %%
import matplotlib.pyplot as plotter
figureObject, axesObject = plotter.subplots()


# Draw the pie chart
axesObject.pie(cologne_grouped,
        autopct='%1.2f',
        startangle=90)
# Aspect ratio - equal means pie is a circle
axesObject.axis('equal')

plotter.show()

# %%
# create map of Cologne using latitude and longitude values
map_food = folium.Map(location=[latitude, longitude], zoom_start=15)

# add markers to map
for lat, lng, name, postalCode in zip(dataframe_filtered['lat'], dataframe_filtered['lng'], dataframe_filtered['name'], dataframe_filtered['postalCode']):
    label = '{}, {}'.format(name, postalCode)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=4,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_food)  
    
map_food
